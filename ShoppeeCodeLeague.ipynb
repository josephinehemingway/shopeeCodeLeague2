# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import json
# %matplotlib inline

df_train = pd.read_csv('train.csv')
df_train
# Out:
#             id                                        raw_address  \
# 0            0  jl kapuk timur delta sili iii lippo cika 11 a ...
# 1            1                                 aye, jati sampurna
# 2            2               setu siung 119 rt 5 1 13880 cipayung
# 3            3                               toko dita, kertosono
# 4            4                                      jl. orde baru
# ...        ...                                                ...
# 299995  299995               jend ahmad yani 331 kertasari ciamis
# 299996  299996                 raya cila kko, cilandak timur kel.
# 299997  299997                     tanjung gusta jl. yaya 2 no 17
# 299998  299998  jalan cipadu jaya taman asri gang bijaksana 3 ...
# 299999  299999          jaya maspion permata blok beryl b2  no.58
#
#                                        POI/street
# 0       /jl kapuk timur delta sili iii lippo cika
# 1                                               /
# ...

# %%
df_test = pd.read_csv('test.csv')
df_test
# Out:
#           id                                        raw_address
# 0          0              s. par 53 sidanegara 4 cilacap tengah
# 1          1              angg per, baloi indah kel. lubuk baja
# 2          2                              asma laun, mand imog,
# 3          3      ud agung rej, raya nga sri wedari karanganyar
# 4          4                         cut mutia, 35 baiturrahman
# ...      ...                                                ...
# 49995  49995                    toko mbak farid semboro semboro
# 49996  49996     vie - tk. ridho kids, vete 3 cari, 16720 ciawi
# 49997  49997                mart dan roti bakar malabar, nasio,
# 49998  49998  graha indah pamulang jl. mujair raya bambu apu...
# 49999  49999                                               adi,
#
# [50000 rows x 2 columns]

# %%
sample_sub = pd.read_csv('sampleSubmission.csv')
sample_sub
# Out:
#    id                   POI/street
# 0   0                            /
# 1   1                    /angg per
# 2   2    asma laundry/mand imogiri
# 3   3  ud agung rejeki/raya ngawi-
# 4   4                   /cut mutia

# %%
df_train['POI/street']
# Out:
# 0         /jl kapuk timur delta sili iii lippo cika
# 1                                                 /
# 2                                            /siung
# 3                                        toko dita/
# 4                                    /jl. orde baru
#                             ...
# 299995                             /jend ahmad yani
# 299996                               /raya cila kko
# 299997                                            /
# 299998                                  taman asri/
# 299999                        jaya maspion permata/
# Name: POI/street, Length: 300000, dtype: object

# %%
#need to split POI and street

splittext = pd.DataFrame(dataset_train['POI/street'].str.split('/'))
splittext
# Out:
#                                           POI/street
# 0       [, jl kapuk timur delta sili iii lippo cika]
# 1                                               [, ]
# 2                                          [, siung]
# 3                                      [toko dita, ]
# 4                                  [, jl. orde baru]
# ...                                              ...
# 299995                                           NaN
# 299996                                           NaN
# 299997                                           NaN
# 299998                                           NaN
# 299999                                           NaN
#
# [600000 rows x 1 columns]

# %%
df1 = pd.DataFrame(splittext['POI/street'].to_list(), columns=['POI','street'])
# frames = [dataset_train, df3]
# dataset_train = pd.concat(frames)
# dataset_train

df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-fa71fb908b4e> in <module>
# ----> 1 df1 = pd.DataFrame(splittext['POI/street'].to_list(), columns=['POI','street'])
#       2 # frames = [dataset_train, df3]
#       3 # dataset_train = pd.concat(frames)
#       4 # dataset_train
#       5
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     472                     if is_named_tuple(data[0]) and columns is None:
#     473                         columns = data[0]._fields
# --> 474                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     475                     columns = ensure_index(columns)
#     476
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
# ...
